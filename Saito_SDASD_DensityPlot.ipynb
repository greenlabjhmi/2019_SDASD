# %%
import pickle
import numpy as np
from pandas import Series, DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import mlab
import seaborn as sns
# %matplotlib inline


mpl.rcParams['xtick.direction'] = 'out'
mpl.rcParams['ytick.direction'] = 'out'

# %%
import pickle

with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks61_3map_readcounts.pickle', 'rb') as f:
    ks61_readcounts = pickle.load(f)
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks61_3map_rpm.pickle', 'rb') as f:
    ks61_rpm = pickle.load(f)
    
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks62_3map_readcounts.pickle', 'rb') as f:
    ks62_readcounts = pickle.load(f)
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks62_3map_rpm.pickle', 'rb') as f:
    ks62_rpm = pickle.load(f)
    
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks63_3map_readcounts.pickle', 'rb') as f:
    ks63_readcounts = pickle.load(f)
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks63_3map_rpm.pickle', 'rb') as f:
    ks63_rpm = pickle.load(f)
    
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks64_3map_readcounts.pickle', 'rb') as f:
    ks64_readcounts = pickle.load(f)
with open('/home/kazuki/^profilingdata/20170615_reanalyze/density/ks64_3map_rpm.pickle', 'rb') as f:
    ks64_rpm = pickle.load(f)

# %%
def rpm_plot_minus(upstream, downstream, readcounts):
    xaxis = range(upstream, downstream+1)
    yaxis =[0 for x in range(upstream, downstream+1)]
    i = 0
    g = upstream-1
    totalread = sum(readcounts)
    while g < downstream:
        yaxis[i]=(readcounts[g]*1E6)/float(totalread)
        i+=1
        g+=1
    yaxis.reverse() 
        # because negative strand
        # x axis is still from upstream to downstrem
        # matplotlib make a bar graph with x axis from smaller number 
        # so the correspondance of x axis and y axis is reversed on the plot
        # I did not yet look for to change the labelling of x axis... 
    return [xaxis,yaxis]

# %%
def rpm_plot_plus(upstream, downstream, readcounts):
    xaxis = range(upstream, downstream+1)
    yaxis =[0 for x in range(upstream, downstream+1)]
    i = 0
    g = upstream-1
    totalread = sum(readcounts)
    while g < downstream:
        yaxis[i]=(readcounts[g]*1E6)/float(totalread)
        i+=1
        g+=1 
    return [xaxis,yaxis]

# %% [markdown]
# # S-ribosome

# %%
# rsmH
# for plus strand

outputfile = 'rpm_rsmH_MutS.pdf'
AUG = 90094
length = 942
distance = 100
upstream = AUG-distance
downstream = AUG+length+distance-1

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([40,80])
plt.ylim(0,92)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks63_readcounts[0]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_plus(upstream, downstream, readcounts)
plt.bar(x_data,data[1], width=10, color="orangered",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1142 artists>

# %%
# rsmH
# for plus strand

outputfile = 'rpm_rsmH_WT.pdf'
AUG = 90094
length = 942
distance = 100
upstream = AUG-distance
downstream = AUG+length+distance-1

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([10,40,80])
plt.ylim(0,92)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks61_readcounts[0]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_plus(upstream, downstream, readcounts)
plt.bar(x_data,data[1], width=10, color="black",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1142 artists>

# %%
# for minus strand

outputfile = 'rpm_sapA_MutS.pdf'
AUG = 1355134
length = 1644
distance = 100
#upstream = AUG-distance
#downstream = AUG+length+distance-1
upstream = AUG+distance-1
downstream = AUG-length-distance

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([40,80])
plt.ylim(0,110)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks63_readcounts[1]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_minus(downstream,upstream, readcounts)
plt.bar(x_data,data[1], width=10, color="orangered",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1844 artists>

# %%
# for minus strand

outputfile = 'rpm_sapA_WT.pdf'
AUG = 1355134
length = 1644
distance = 100
#upstream = AUG-distance
#downstream = AUG+length+distance-1
upstream = AUG+distance-1
downstream = AUG-length-distance

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([10,40,80])
plt.ylim(0,110)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks61_readcounts[1]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_minus(downstream,upstream, readcounts)
plt.bar(x_data,data[1], width=10, color="black",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1844 artists>

# %% [markdown]
# # O-ribosome

# %%
# hemA
#  for plus strand

AUG = 1262937 
length = 1257
distance = 100
upstream = AUG-distance
downstream = AUG+length+distance-1

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([50,100])
plt.ylim(0,130)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks62_readcounts[0]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_plus(upstream, downstream, readcounts)
plt.bar(x_data,data[1], width=10, color="cornflowerblue",linewidth = 0)

#plt.savefig('rpm_hemA_mutO.pdf', dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1457 artists>

# %%
# hemA
#  for plus strand

AUG = 1262937 
length = 1257
distance = 100
upstream = AUG-distance
downstream = AUG+length+distance-1

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([25,50,75,100,125])
plt.ylim(0,130)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks61_readcounts[0]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_plus(upstream, downstream, readcounts)
plt.bar(x_data,data[1], width=10, color="black",linewidth = 0)

#plt.savefig('rpm_hemA_WT.pdf', dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1457 artists>

# %%
#  for plus strand

outputfile = 'rpm_rbsK_mutO.pdf'
AUG = 3935317 
length = 930
distance = 100
upstream = AUG-distance
downstream = AUG+length+distance-1

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([100,200])
plt.ylim(0,290)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks62_readcounts[0]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_plus(upstream, downstream, readcounts)
plt.bar(x_data,data[1], width=10, color="cornflowerblue",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1130 artists>

# %%
#  for plus strand

outputfile = 'rpm_rbsK_wt.pdf'
AUG = 3935317 
length = 930
distance = 100
upstream = AUG-distance
downstream = AUG+length+distance-1

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([30,200])
plt.ylim(0,290)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks61_readcounts[0]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_plus(upstream, downstream, readcounts)
plt.bar(x_data,data[1], width=10, color="black",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1130 artists>

# %%
# for minus strand

outputfile = 'rpm_mreB_MutO.pdf'
AUG = 3399109
length = 1044
distance = 100
#upstream = AUG-distance
#downstream = AUG+length+distance-1
upstream = AUG+distance-1
downstream = AUG-length-distance

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([500,1000,1500])
plt.ylim(0,1700)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks62_readcounts[1]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_minus(downstream,upstream, readcounts)
plt.bar(x_data,data[1], width=10, color="cornflowerblue",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1244 artists>

# %%
outputfile = 'rpm_mreB_WT.pdf'
AUG = 3399109
length = 1044
distance = 100
#upstream = AUG-distance
#downstream = AUG+length+distance-1
upstream = AUG+distance-1
downstream = AUG-length-distance

x_data = [x for x in range (1,length+distance*2+1)]

fig, ax = plt.subplots()
fig.set_dpi(500)
fig.set_size_inches(4, 2)
plt.xticks([distance,distance+length])
plt.xlim(0,distance+length+distance)
plt.yticks([200,1000,1500])
plt.ylim(0,1700)
plt.tick_params(labelsize=7)
sns.despine()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

readcounts = ks61_readcounts[1]['gi|49175990|ref|NC_000913.2|']
data=rpm_plot_minus(downstream,upstream, readcounts)
plt.bar(x_data,data[1], width=10, color="black",linewidth = 0)

#plt.savefig(outputfile, dpi=500, bbox_inches="tight", pad_inches=0.0)
# Out:
# <Container object of 1244 artists>
